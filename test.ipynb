# %%
 from dev_tools import say_hello
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from dev_tools import say_hello
#
# File d:\Sky_Analytics\dev_tools.py:42
#      40 # Boucle pour exécuter les tâches planifiées
#      41 while datetime.now() < end_date:
# ---> 42     schedule.run_pending()
#      43     time.sleep(1)
#      44 print("Fin du programme")
#
# File c:\Users\pnii\AppData\Local\Programs\Python\Python312\Lib\site-packages\schedule\__init__.py:854, in run_pending()
#     850 def run_pending() -> None:
#     851     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     852     :data:`default scheduler instance <default_scheduler>`.
#     853     """
# --> 854     default_scheduler.run_pending()
#
# File c:\Users\pnii\AppData\Local\Programs\Python\Python312\Lib\site-packages\schedule\__init__.py:101, in Scheduler.run_pending(self)
# ...

# %%
say_hello('manish')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 say_hello('manish')
#
# NameError: name 'say_hello' is not defined
