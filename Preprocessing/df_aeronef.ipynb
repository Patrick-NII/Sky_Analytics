# %%
from skimpy import skim
import json 
import requests 
import pandas as pd
from pandas import json_normalize 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from dev_tools import autoclean_dataset, say_hello

# %%
df_aeronef = autoclean_dataset('D:\\Sky_Analytics\\Datasets\\df_aeronef\\aeronefs_2024-06-02.csv')
# Out:
# Résumé des données :
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 232    │ │ string      │ 5     │                                                          │
# │ │ Number of columns │ 6      │ │ bool        │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# ...

# %%
df_aeronef = pd.read_csv('D:\\Sky_Analytics\\Datasets\\df_aeronef\\aeronefs_2024-06-02.csv')

# %%
# Ici nous retrouvons les doublons dans le dataset df_aeronef
df_aeronef[df_aeronef['ref_aero'].duplicated(keep=False)]
# Out:
#       ref_aero type_model debut_service           last_maint  en_maintenance  \
# 40   E170_5551       E170    2017-02-07  2024-06-01 00:00:00           False
# 230  E170_5551       E170    2021-04-10  2024-06-01 00:00:00           False
#
#     end_maint
# 40        NaN
# 230       NaN

# %%
# Vérification des doublons trouver dans la table 'df_aeronef' de la tables 'df_composants'
df_composants = pd.read_csv('D:\\Sky_Analytics\\Datasets\\df_composants\\composants_2024-06-02.csv')
df_composants[df_composants['aero'] == 'E170_5551'].head()
# Out:
#                 ref_compo             categorie       aero  \
# 1800  REAE170-E170_5551-0  Composants Critiques  E170_5551
# 1801  REAE170-E170_5551-1  Composants Critiques  E170_5551
# 1802  SYSE170-E170_5551-2  Composants Critiques  E170_5551
# 1803  ORDE170-E170_5551-3  Composants Critiques  E170_5551
# 1804  AUTE170-E170_5551-4  Composants Critiques  E170_5551
#
#                        desc  lifespan  taux_usure_actuel   cout
# 1800        Réacteur gauche     13045          33.472770  15552
# 1801         Réacteur droit     13626          41.964356  17559
# 1802  Système de navigation     10541           2.467346  16514
# 1803      Ordinateur de vol     10441          35.576746  16047
# 1804             Autopilote     14847          24.763782  19362

# %%
# Vérification des doublons trouver dans la table 'df_aeronef' de la tables 'logs_vols'
df_logs_vols = pd.read_csv('D:\\Sky_Analytics\\Datasets\\df_logs_vols\\logs_vols.csv')
df_logs_vols.head()
# Out:
#      ref_vol aero_linked    jour_vol  time_en_air  etat_voyant     temp  \
# 0  V07679725   B767_4924  2024-06-02          7.0            0   -5.7°C
# 1  V02564879   B747_3165  2024-06-02          5.1            0    0.9°C
# 2  V07933973   B757_2518  2024-06-02          7.7            3   -6.2°C
# 3  V02230187   A340_1047  2024-06-02          6.1            1  -25.3°C
# 4  V09071213   B757_6806  2024-06-02          4.5            0   11.1°C
#
#     pressure               vibrations
# 0  930.6 hPa  3.1163905014858932 m/s²
# 1  950.6 hPa  4.5578253809563725 m/s²
# 2  975.5 hPa    4.58707061982232 m/s²
# 3  945.1 hPa   3.287868564197513 m/s²
# 4  931.3 hPa  2.8166257793381355 m/s²

# %%
# Vérification des doublons trouver dans la table 'df_aeronef' de la tables 'df_degradations'
df_degrade = pd.read_csv('D:\\Sky_Analytics\\Datasets\\df_degradations\\degradations.csv')
df_degrade.head()
# Out:
#    ref_deg linked_aero      compo_concerned  usure_nouvelle measure_day  \
# 0  D003661   E170_6353  REAE170-E170_6353-0       53.308375  2024-06-01
# 1  D009402   E170_6353  REAE170-E170_6353-1       50.111950  2024-06-01
# 2  D000812   E170_6353  SYSE170-E170_6353-2       16.730575  2024-06-01
# 3  D006665   E170_6353  ORDE170-E170_6353-3        6.653075  2024-06-01
# 4  D001163   E170_6353  AUTE170-E170_6353-4       42.033525  2024-06-01
#
#    need_replacement
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %%
say_hello('Ulrich')
# Out:
# 'Hello Ulrich !'
